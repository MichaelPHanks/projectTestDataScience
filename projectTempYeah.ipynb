# %%
import pandas as pd

# %%
df = pd.read_csv('People.csv')
df.head()
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  aardsda01     1981.0        12.0      27.0          USA         CO
# 1  aaronha01     1934.0         2.0       5.0          USA         AL
# 2  aaronto01     1939.0         8.0       5.0          USA         AL
# 3   aasedo01     1954.0         9.0       8.0          USA         CA
# 4   abadan01     1972.0         8.0      25.0          USA         FL
#
#     birthCity  deathYear  deathMonth  deathDay  ... nameLast       nameGiven  \
# 0      Denver        NaN         NaN       NaN  ...  Aardsma     David Allan
# 1      Mobile        NaN         NaN       NaN  ...    Aaron     Henry Louis
# 2      Mobile     1984.0         8.0      16.0  ...    Aaron      Tommie Lee
# 3      Orange        NaN         NaN       NaN  ...     Aase  Donald William
# 4  Palm Beach        NaN         NaN       NaN  ...     Abad   Fausto Andres
#
#   weight height bats throws       debut   finalGame   retroID    bbrefID
# ...

# %%
columns = ['playerID', 'nameFirst', 'nameLast', 'weight', 'birthYear',
'birthCountry', 'finalGame']
players = df[columns]
players.head()
#players[(players.nameFirst == 'John') & (players.birthYear > 1972) &
#(players.birthYear < 1976)]
# Out:
#     playerID nameFirst nameLast  weight  birthYear birthCountry   finalGame
# 0  aardsda01     David  Aardsma   215.0     1981.0          USA  2015-08-23
# 1  aaronha01      Hank    Aaron   180.0     1934.0          USA  1976-10-03
# 2  aaronto01    Tommie    Aaron   190.0     1939.0          USA  1971-09-26
# 3   aasedo01       Don     Aase   190.0     1954.0          USA  1990-10-03
# 4   abadan01      Andy     Abad   184.0     1972.0          USA  2006-04-13
